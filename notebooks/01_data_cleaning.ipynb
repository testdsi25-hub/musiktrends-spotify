# %%
import pandas as pd
import os

# %%
# Pfad definieren
file_path = ("../data/raw/spotify-weekly/charts.csv")

# %%
if os.path.exists(file_path):
    # großer Datensatz: für ersten Eindruck auf 10.000 Zeilen beschränken
    charts = pd.read_csv(file_path, nrows=10000)
    print(f"Erfolgreich geladen: {charts.shape[0]} Zeilen.")
    display(charts.head())
else:
    print(f"Datei nicht gefunden unter: {os.path.abspath(file_path)}")
# Out:
# Erfolgreich geladen: 10000 Zeilen.
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# ...
